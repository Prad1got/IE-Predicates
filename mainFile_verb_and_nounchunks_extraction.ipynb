# %% [markdown]
# ## Extraction and comparison of noun chunks and verbs with manually annotated noun chunks and verbs.

# %%
#!pip install textacy
import os
import spacy
##import textacy
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk import RegexpParser
import re
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 563 kB/s
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.3.0) (3.3.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.11.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.17)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.23.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.64.0)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2022.6.15)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# # For dataset.

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/content/manually-annotated-scienceDataset1.csv',index_col=False)

# %%
df1.head()
# Out:
#    no                                           sentence  \
# 0   1  There are six main nutrients in our food : Car...
# 1   2  These nutrients are present in the different f...
# 2   3                        Our main need is of energy.
# 3   4               Let us learn more about some of them
# 4   5                   It is fulfilled by carbohydrates
#
#                                              n(list)           v(list)
# 0  There, six main nutrients, our food,Carbohydra...               are
# 1  These nutrients, the different food items, we,...  are present, eat
# 2                             Our main need , energy                is
# 3                                    us, some , them        let, learn
# 4                                 It , carbohydrates      is fulfilled

# %%
df1['v(list)'].fillna("not_a_verb",inplace=True)

# %%
# Function to extract the verbs
def verbExtractor(text):
    verbs = []  
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        #words = [word for word in words if word not in set(stopwords.words('english'))]     not used in our case.
        #print(words)                       for debugging purpose
        tagged = nltk.pos_tag(words)
        #print(tagged)                      for debugging purpose
        for (word, val) in tagged:                
            if (val == 'VBP' or val == 'VB' or val == 'VBG' or val == 'VBD' or val == 'VBZ' or val == 'VBN'):         #Extracting verb if the word is a verb
                verbs.append(word)
    return verbs

# %%
listofnouns = []
listofverbs = []
nlp = spacy.load("en_core_web_sm")
for i in df1['sentence']:
  listofsentence = []
  doc =nlp(i)
  for np in doc.noun_chunks:
    listofsentence.append(np.text)
  listofverbs.append(verbExtractor(i))
  listofnouns.append(listofsentence)

# %%
listofnouns
# Out:
# [['six main nutrients',
#   'our food',
#   'Carbohydrates',
#   'fats',
#   'proteins',
#   'fibre',
#   'vitamins',
#   'minerals'],
#  ['These nutrients',
#   'the different food items',
#   'we',
#   'differing proportions'],
#  ['Our main need', 'energy'],
#  ['us', 'some', 'them'],
#  ['It', 'carbohydrates'],
#  ['our diet',
#   'a large proportion',
#   'cereals',
#   'the form',
#   'rice',
#   'chapatti',
#   'roti',
#   'bhakri',
#   'bread',
#   'which',
#   'carbohydrates'],
#  ['We',
#   'proteins',
#   'the purposes',
#   'growth',
#   'the wear',
#   'tear',
#   'the body',
#   'other life processes'],
#  ['We',
#   'proteins',
#   'the sprouts',
#   'milk',
#   'milk',
#   'products',
#   'meat',
#   'eggs',
#   'our food'],
#  ['Some part',
#   'our energy requirement',
#   'fatty foods',
#   'oil',
#   'ghee',
#   'butter'],
#  ['We', 'energy', 'the form', 'heat', 'the food', 'we'],
#  ['Heat', 'kilocalories'],
#  ['the energy', 'food items', 'kilocalories', 'Calories'],
#  ['Minerals',
#   'vitamins',
#   "the body's resistance",
#   'disease',
#   'other life',
#   'the body',
#   'vitamins',
#   'minerals',
#   'fibre',
#   'the diet'],
#  ['We', 'these nutrients', 'vegetables', 'fruits'],
#  ['We',
#   'vitamins',
#   'minerals',
#   'small quantities',
#   'their deficiency',
#   'various diseases'],
#  ['us', 'them'],
#  ['The body', 'several inorganic substances'],
#  ['The table',
#   'examples',
#   'some minerals',
#   'information',
#   'their functions',
#   'the body',
#   'the various sources',
#   'the minerals',
#   'the diseases',
#   'their deficiency'],
#  ['Calcium', 'a mineral', 'which', 'bones', 'teeth'],
#  ['We',
#   'proteins',
#   'the purposes',
#   'growth',
#   'the wear',
#   'tear',
#   'the body',
#   'other life processes'],
#  ['We',
#   'proteins',
#   'the sprouts',
#   'milk',
#   'milk',
#   'products',
#   'meat',
#   'eggs',
#   'our food'],
#  ["the body's  resistance",
#   'disease',
#   'other life',
#   'the bodyneeds vitamins',
#   'minerals',
#   'fibre',
#   'the diet'],
#  ['We', 'these nutrients', 'vegetables', 'fruits'],
#  ['Our main need', 'energy'],
#  ['It', 'carbohydrates'],
#  ['our diet',
#   'a large proportion',
#   'cereals',
#   'the form',
#   'rice',
#   'chapatti',
#   'roti',
#   'bhakri',
#   'bread',
#   'which',
#   'carbohydrates'],
#  ['Cereals', 'our staple food'],
#  ['Starch', 'blackish blue', 'it', 'contact', 'iodine'],
#  ['we', 'starch', 'the potato'],
#  ['Sago', 'sweet potato', 'starch'],
#  ['Cereals', 'jowar', 'bajra', 'wheat', 'rice', 'a lot', 'starch'],
#  ['We', 'flour', 'these grains'],
#  ['These grains', 'our staple diet'],
#  ['We', 'energy', 'starchy foods'],
#  ['Food-stuffs', 'that', 'different kinds', 'sugars'],
#  ['example',
#   'we',
#   'jiggery',
#   'table sugar',
#   'sugarcane',
#   'it',
#   'a sugar',
#   'sucrose'],
#  ['Ripe fruits',
#   'mango, banana, chickoo',
#   'honey',
#   'milk',
#   'various kinds',
#   'sugars'],
#  ['They', 'us', 'energy'],
#  ['Plants', 'their own food', 'sunlight'],
#  ['Plants',
#   'food',
#   'water',
#   'nutrients',
#   'the soil',
#   'the carbon dioxide',
#   'the air'],
#  ['This process', 'place', 'the leaves', 'plants'],
#  ['It',
#   'the presence',
#   'sunlight',
#   'the help',
#   'the chlorophyll',
#   'the leaves'],
#  ['This process', 'food production', 'photosynthesis'],
#  ['this process', 'plants', 'oxygen'],
#  ['Living things', 'small units', 'cells'],
#  ['All the actions',
#   'processes',
#   'the bodies',
#   'living things',
#   'the help',
#   'these microscopic cells'],
#  ['Animals',
#   'snails',
#   'cockroaches',
#   'earthworms',
#   'a vertebral column',
#   'they',
#   'invertebrate animals'],
#  ['They', 'minerals'],
#  ['Plants', 'colour', 'the chlorophyll', 'them'],
#  ['Living things', 'small units', 'cells'],
#  ['All the actions',
#   'processes',
#   'the bodies',
#   'living things',
#   'the help',
#   'these microscopic cells'],
#  ['Some living things', 'a single cell'],
#  ['These', 'unicellular organisms'],
#  ['the other hand',
#   'the living things',
#   'that',
#   'many cells',
#   'multicellular organisms'],
#  ['The amoeba',
#   'some other microorganisms',
#   'man',
#   'cow',
#   'mouse',
#   'cockroach',
#   'elephants',
#   'banyan tree',
#   'the onion plant',
#   'multicellular organisms'],
#  ['All the characteristics',
#   'living things',
#   'every cell',
#   'a living thing',
#   'it'],
#  ['A cellular structure', 'you'],
#  ['The lifespan',
#   'the giant turtle',
#   'the Galapagos Island',
#   'South America',
#   'about 170 years'],
#  ['the other hand', 'the lifespan', 'the mayfly', '1 hour', '24 hours'],
#  ['Living things', 'small units', 'cells'],
#  ['All the actions',
#   'processes',
#   'the bodies',
#   'living things',
#   'the help',
#   'these microscopic cells'],
#  ['Some living things', 'a single cell'],
#  ['These', 'unicellular organisms'],
#  ['the other hand',
#   'the living things',
#   'that',
#   'many cells',
#   'multicellular organisms'],
#  ['The amoeba',
#   'some other microorganisms',
#   'man',
#   'cow',
#   'mouse',
#   'cockroach',
#   'elephants',
#   'banyan tree',
#   'the onion plant',
#   'multicellular organisms'],
#  ['All the characteristics',
#   'living things',
#   'every cell',
#   'a living thing',
#   'it'],
#  ['Waste substances',
#   'the many processes',
#   'that',
#   'place',
#   'the bodies',
#   'animals'],
#  ['These', 'excreta', 'the process', 'them', 'the body'],
#  ['Animals', 'specific organs', 'excretion'],
#  ['Plants', 'excrete'],
#  ['example', 'some plants', 'leaves', 'a specific season'],
#  ['Waste substances', 'the leaves', 'plants', 'the leaves'],
#  ['Reproduction Living things', 'other living things', 'themselves'],
#  ['Some animals', 'birth', 'their young ones'],
#  ['Their young ones', 'the eggs'],
#  ['New plants', 'the seeds', 'leaves', 'plants'],
#  ['The process',
#   'which',
#   'a living thing',
#   'a new living thing',
#   'itself',
#   'reproduction',
#   'procreation'],
#  ['a certain stage', 'life', 'living things', 'reproduction'],
#  ['so many types', 'plants', 'animals', 'the earth'],
#  ['A mare', 'her foal Reproduction', 'a characteristic', 'living things'],
#  ['a certain stage', 'life', 'living things', 'reproduction'],
#  ['life reproduction stage', 'their organs', 'their life', 'an end'],
#  ['other words', 'living things'],
#  ['The lifespans', 'different animals', 'plants'],
#  ['example',
#   'the lifespan',
#   'the dog',
#   'about 12 to 18 years',
#   'the ostrich',
#   '50 years'],
#  ['You',
#   'what',
#   'the living things',
#   'they',
#   'being',
#   'We',
#   'another living thing',
#   'oneself',
#   'reproduction'],
#  ['A hen', 'eggs', 'them'],
#  ['a few days', 'the young chicks', 'the eggs'],
#  ['A cow', 'birth', 'a calf'],
#  ['that', 'the calf', 'the cows body'],
#  ['the mode',
#   'reproduction',
#   'animals',
#   'two types',
#   'namely, oviparous animals',
#   'which',
#   'eggs',
#   'viviparous animals',
#   'which',
#   'birth',
#   'their young ones'],
#  ['Some plants', 'the ground'],
#  ['They', 'branches', 'the ground'],
#  ['They', 'trees', 'they', 'a thick and hard stem'],
#  ['The oleander',
#   'hibiscus',
#   'lantana',
#   'koranti',
#   'shrubs',
#   'that',
#   'two to three metres'],
#  ['Herbs'],
#  ['The stems', 'herbs', 'those', 'trees', 'bushes'],
#  ['Herbs', 'a few months', 'up to two years'],
#  ['you',
#   'vines',
#   'the pumpkin',
#   'the railroad creeper',
#   'kavali',
#   'watermelon',
#   'the grapevine'],
#  ['The lifecycle', 'plants', 'jowar', 'sunflower', 'one year'],
#  ['These plants', 'annuals'],
#  ['The lifecycle', 'plants', 'the carrot', 'beetroot', 'two years'],
#  ['They', 'biennials'],
#  ['Shrubs',
#   'the hibiscus',
#   'oleander',
#   'trees',
#   'mango',
#   'gulmohur',
#   'several years',
#   'flowers',
#   'fruit'],
#  ['They', 'perennials'],
#  ['the period',
#   'their lifecycle',
#   'plants',
#   'annuals',
#   'biennials',
#   'perennials'],
#  ['Some plants'],
#  ['Their stem', 'trunk'],
#  ['They', 'branches', 'some height', 'the ground'],
#  ['They', 'flowers', 'fruit', 'many years'],
#  ['Such plants', 'trees'],
#  ['Trees', 'they', 'many years'],
#  ['a piece', 'a metal', 'one place', 'the whole', 'it'],
#  ['It', 'metals', 'heat', 'them'],
#  ['This property', 'thermal conductivity'],
#  ['Delicate articles', 'perishable fruits', 'packing'],
#  ['TV sets', 'refrigerators', '. big cartons', 'thermocol'],
#  ['All these', 'man-made substances'],
#  ['These substances', 'water proof'],
#  ['That', 'they'],
#  ['New Topic biodiversity',
#   'evaluation',
#   'Every living thing',
#   'its food',
#   'the environment'],
#  ['Many animals', 'the environment', 'only plants'],
#  ['Other animals', 'the animals', 'that', 'plants'],
#  ['plants',
#   'their own food',
#   'the presence',
#   'sunlight',
#   'water',
#   'the carbon dioxide',
#   'the air'],
#  ['It', 'plants', 'the main support', 'every food chain'],
#  ['Every living thing', 'its food', 'the environment'],
#  ['Many animals', 'the environment', 'only plants'],
#  ['Other animals', 'the animals', 'that', 'plants'],
#  ['plants',
#   'their own food',
#   'the presence',
#   'sunlight',
#   'water',
#   'the carbon dioxide',
#   'the air'],
#  ['It', 'plants', 'the main support', 'every food chain'],
#  ['Ball',
#   'this type',
#   'joint',
#   'the bones',
#   'two or more directions',
#   'a 3600 angle'],
#  ['Examples', 'shoulder', 'hip joints'],
#  ['The skull', 'the bones', 'the head', 'face'],
#  ['The bones', 'the skull'],
#  ['22 bones', 'the skull', 'the head', 'the face'],
#  ['the lower jaw', 'none', 'the bones', 'the skull'],
#  ['The spine', 'padlock-shaped bones'],
#  ['33 bones', 'the spine', 'a vertebra'],
#  ['These bones'],
#  ['The spine', 'the spinal cord', 'that', 'the brain'],
#  ['The germs',
#   'diseases',
#   'the intestines',
#   'typhoid',
#   'cholera',
#   'diarrhoea',
#   'jaundice',
#   'the faeces',
#   'the affected person'],
#  ['the faeces', 'water', 'the germs', 'it', 'the water'],
#  ['another person',
#   'water',
#   'which',
#   'these germs',
#   'they',
#   'his intestines',
#   'that person',
#   'the disease'],
#  ['the spread',
#   'disease',
#   'this manner',
#   'it',
#   'washing clothes',
#   'the water sources',
#   'the banks',
#   'the water'],
#  ['Germs', 'diseases', 'the flu', 'conjunctivitis', 'the air'],
#  ['many people', 'such diseases', 'one time'],
#  ['the water',
#   'a common source',
#   'germs',
#   'a disease',
#   'cholera',
#   'the danger',
#   'all those',
#   'who',
#   'that water',
#   'the disease'],
#  ['some place', 'mosquitoes', 'large numbers', 'many people'],
#  ['microorganisms', 'our body', 'the body', 'the disease', 'the germs'],
#  ['That', 'we', 'a disease', 'germs', 'our body'],
#  ['Another way', 'disease', 'vaccination'],
#  ['Our body', 'resistance', 'a particular disease', 'vaccination'],
#  ['Some', 'eggs'],
#  ['The process', 'which', 'the seeds', 'the mother plants', 'dispersal'],
#  ['Nature', 'its own ways', 'dispersal', 'seeds'],
#  ['Dispersal', 'wind \\u2013 Seeds', 'certain plants', 'wings hair', 'them'],
#  ['These seeds', 'wind'],
#  ['Sycamore Plants', 'seeds', 'that', 'wind'],
#  ['Dandelion Seeds', 'hair', 'that', 'a parachute'],
#  ['The fluff', 'the cotton seeds', 'the wind'],
#  ['Dispersal',
#   'Animals \\u2013 Animals',
#   'human beings',
#   'some fruits',
#   'the seeds',
#   'which',
#   'new plants'],
#  ['Certain seeds', 'stiff hairs', 'spines', 'which', 'their dispersal'],
#  ['Some seeds', 'spins', 'hooks'],
#  ['These seeds', 'the body', 'animals', 'birds', 'the parent plants'],
#  ['Birds', 'animals', 'fruits seeds', 'their digestive system', 'other areas'],
#  ['Squirrels', 'seeds', 'nuts', 'them', 'winter'],
#  ['squirrel', 'they', 'bury seeds'],
#  ['Dispersal',
#   'water \\u2013 seeds',
#   'some plants',
#   'lotus',
#   'coconut',
#   'fibrous covering',
#   'which',
#   'them',
#   'water'],
#  ['Water', 'these seeds', 'one place', 'another'],
#  ['Coconuts', 'oceans'],
#  ['the coconut palms', 'south sea islands', 'coconuts', 'ocean currents'],
#  ['Explosion \\u2013 Fruits',
#   'certain plants',
#   'pea',
#   'beans',
#   'they',
#   'the seeds',
#   'all directions'],
#  ['This mechanism', 'seeds dispersal', 'explosion'],
#  ['jowar', 'wheat', 'a flour', 'the particles', 'the flour'],
#  ['the flour', 'we', 'the larger particles', 'the sieve'],
#  ['These particles', 'fine pieces', 'the skin', 'bran', 'the grain'],
#  ['Bran', 'a fibrous substance'],
#  ['the process', 'digestion', 'fibre', 'a special function'],
#  ['Fibrous substances', 'the food', 'the alimentary canal', 'the right speed'],
#  ['The undigested food', 'no use', 'the body'],
#  ['Fibre', 'stool', 'this undigested food'],
#  ['Fibre', '\\u2018roughage\\u2019'],
#  ['Fruits',
#   'vegetables',
#   'especially their skins',
#   'whole grains',
#   'pulses',
#   'sources',
#   'fibre',
#   'food'],
#  ['our food', 'enough fibre', 'it', 'constipation'],
#  ['we',
#   'about three types',
#   'substances',
#   'our food starch',
#   'sugar',
#   'fibre'],
#  ['These substances', 'carbohydrates'],
#  ['The most important use', 'carbohydrates', 'the body', 'energy'],
#  ['stones',
#   'bricks',
#   'the building blocks',
#   'a wall',
#   'proteins',
#   'the building blocks',
#   'our body'],
#  ['The body'],
#  ['it'],
#  ['the healing', 'repair', 'our body', 'all the time', 'our', 'it'],
#  ['Proteins', 'that purpose'],
#  ['Proteins', 'plenty', 'the growing years', 'a person\\u2019s life'],
#  ['All the different daals',
#   'pulses',
#   'groundnuts',
#   'milk',
#   'milk products',
#   'yoghurt',
#   'khoya',
#   'paneer',
#   'eggs',
#   'meat',
#   'fish',
#   'rich sources',
#   'proteins'],
#  ['the required proteins',
#   'our daily diet',
#   'daals',
#   'pulses',
#   'milk and milk products'],
#  ['Minerals',
#   'Iron',
#   'calcium',
#   'sodium',
#   'potassium',
#   'examples',
#   'minerals',
#   'that',
#   'the body'],
#  ['They',
#   'very small quantities',
#   'they',
#   'an important part',
#   'all the necessary functions',
#   'our body'],
#  ['example', 'iron', 'oxygen', 'different parts', 'the body'],
#  ['a deficiency',
#   'iron',
#   'the blood',
#   'the body',
#   'enough supply',
#   'oxygen',
#   'one'],
#  ['This condition', '\\u2018anaemia\\u2019'],
#  ['These seeds', 'new plants'],
#  ['The mineral calcium', 'our bones'],
#  ['All kinds',
#   'fruits',
#   'vegetables',
#   'green leafy vegetables',
#   'sprouted pulses',
#   'their skins',
#   'the bran',
#   'cereals',
#   'pulses',
#   'sources',
#   'vitamins',
#   'minerals'],
#  ['That', 'we', 'fruits', 'their skins', 'we', 'flour', 'the bran'],
#  ['your hand', 'front', 'your nose', 'your hand', 'your chest'],
#  ['What', 'you'],
#  ['we', 'a sleeping dog', 'what movement', 'its belly', 'we'],
#  ['Living things', 'oxygen', 'order'],
#  ['oxygen',
#   'the carbon dioxide',
#   'the body',
#   'the use',
#   'oxygen',
#   'respiration'],
#  ['Animals', 'fish', 'snake', 'mouse', 'specific organs', 'respiration'],
#  ['the other hand',
#   'plants',
#   'means',
#   'microscopic pores',
#   'their stems',
#   'leaves'],
#  ['Some plants'],
#  ['Their stem', 'trunk'],
#  ['They', 'branches', 'some height', 'the ground'],
#  ['They', 'flowers', 'fruit', 'many years'],
#  ['Such plants', 'trees'],
#  ['Trees', 'they', 'many years'],
#  ['Electricity', 'metals'],
#  ['All metals', 'conductors', 'electricity', 'a greater or lesser extent'],
#  ['This property', 'electrical conductivity'],
#  ['a piece', 'a metal', 'one place', 'the whole', 'it'],
#  ['It', 'metals', 'heat', 'them'],
#  ['This property', 'thermal conductivity'],
#  ['Metals', 'a typical shine', 'lustre'],
#  ['Every metal', 'a characteristic colour', 'which', 'it'],
#  ['we', 'a substance', 'things', 'the other side', 'that substance'],
#  ['you', 'some states', 'our country', 'cotton'],
#  ['The fruits', 'the cotton plant', '(cotton bolls', 'the size', 'a lemon'],
#  ['the bolls', 'the seeds', 'cotton fibres'],
#  ['you', 'a cotton field', 'that'],
#  ['It', 'a field', 'snow.na', 'these bolls', 'cotton', 'hand'],
#  ['Fibres', 'the seeds'],
#  ['This process', 'ginning', 'cotton'],
#  ['Ginning', 'hand', '(Fig.3.7'],
#  ['machines', 'ginning']]

# %%
listofverbs
# Out:
# [['are'],
#  ['are', 'eat', 'differing'],
#  ['is'],
#  ['Let', 'learn'],
#  ['is', 'fulfilled'],
#  ['includes', 'contain'],
#  ['need', 'repairing'],
#  ['get'],
#  ['is', 'fulfilled'],
#  ['get', 'eat'],
#  ['is', 'measured'],
#  ['is', 'measured'],
#  ['improve', 'disease', 'processes', 'needs'],
#  ['obtain'],
#  ['require', 'lead'],
#  ['Let', 'learn'],
#  ['needs'],
#  ['gives', 'provides', 'caused'],
#  ['is', 'strengthen'],
#  ['need', 'repairing'],
#  ['get'],
#  ['improve', 'disease', 'processes'],
#  ['obtain'],
#  ['is'],
#  ['is', 'fulfilled'],
#  ['includes'],
#  ['are'],
#  ['turns', 'comes'],
#  ['infer', 'is'],
#  ['contain'],
#  ['contain'],
#  ['obtain', 'flour'],
#  ['form'],
#  ['get'],
#  ['taste'],
#  ['get', 'contains', 'called'],
#  ['contain'],
#  ['give'],
#  ['make'],
#  ['produce'],
#  ['takes'],
#  ['is', 'brought'],
#  ['is', 'called'],
#  ['give'],
#  ['Living', 'are', 'made', 'called'],
#  ['are', 'brought'],
#  ['do', 'have', 'are'],
#  ['are', 'called'],
#  ['appear'],
#  ['Living', 'are', 'made', 'called'],
#  ['are', 'brought'],
#  ['are', 'made'],
#  ['are', 'called'],
#  ['are', 'made', 'are', 'called'],
#  ['are', 'are'],
#  ['are', 'seen', 'is'],
#  ['know'],
#  ['found', 'is'],
#  ['ranges'],
#  ['Living', 'are', 'made', 'called'],
#  ['are', 'brought'],
#  ['are', 'made'],
#  ['are', 'called'],
#  ['are', 'made', 'are', 'called'],
#  ['are', 'are'],
#  ['are', 'seen', 'is'],
#  ['are', 'formed', 'processes', 'take'],
#  ['are', 'called', 'eliminating', 'is', 'called'],
#  ['have'],
#  [],
#  ['shed'],
#  ['stored', 'are', 'shed'],
#  ['Living', 'produce'],
#  ['give'],
#  ['hatch'],
#  ['are', 'produced', 'stems'],
#  ['generates', 'is', 'called'],
#  ['living', 'become'],
#  ['have', 'been', 'survive'],
#  ['is'],
#  ['living', 'become'],
#  ['become', 'comes'],
#  ['living'],
#  ['are'],
#  ['is', 'lives'],
#  ['have',
#   'wondered',
#   'are',
#   'came',
#   'being',
#   'have',
#   'learnt',
#   'producing',
#   'living',
#   'is',
#   'called'],
#  ['lays'],
#  ['hatch'],
#  ['gives'],
#  ['grows'],
#  ['According', 'are', 'classified', 'lay', 'give'],
#  ['grow'],
#  ['give'],
#  ['are', 'have'],
#  ['rose', 'are', 'grow'],
#  ['grow'],
#  ['are', 'compared'],
#  ['live'],
#  ['Have', 'seen'],
#  ['is', 'completed'],
#  ['are', 'called'],
#  ['is'],
#  ['are', 'called'],
#  ['live'],
#  ['are', 'called'],
#  ['According', 'are', 'classified'],
#  ['grow'],
#  ['is'],
#  ['have'],
#  ['bear'],
#  ['are', 'called'],
#  ['are', 'live'],
#  ['is', 'heated', 'becomes'],
#  ['shows', 'allow', 'flow'],
#  ['is', 'called'],
#  [],
#  ['pack', 'are', 'being', 'used'],
#  ['are'],
#  ['are', 'transport'],
#  ['is', 'are', 'being', 'used'],
#  ['gets'],
#  [],
#  ['eat', 'live'],
#  ['make', 'using'],
#  ['means', 'are'],
#  ['gets'],
#  [],
#  ['eat', 'live'],
#  ['make', 'using'],
#  ['means', 'are'],
#  ['move'],
#  [],
#  ['is', 'formed'],
#  ['are'],
#  ['are'],
#  ['move'],
#  ['is', 'formed', 'placed'],
#  ['are', 'called'],
#  ['are', 'arranged'],
#  ['protects', 'originates'],
#  ['are'],
#  ['get', 'enter'],
#  ['has', 'been', 'contaminated', 'enter', 'get'],
#  ['prevent', 'is', 'avoid', 'washing', 'bathing', 'defecating'],
#  [],
#  ['get'],
#  ['is', 'contaminated', 'is', 'drink', 'getting'],
#  ['breed', 'get'],
#  ['producing', 'resists', 'fights'],
#  ['is', 'do', 'get', 'enter'],
#  ['prevent', 'is'],
#  ['develops'],
#  [],
#  ['are', 'scattered', 'is', 'called'],
#  ['has'],
#  ['are', 'have', 'hair'],
#  ['are', 'carried'],
#  ['has', 'winged', 'are', 'carried'],
#  ['have', 'hair'],
#  ['helps', 'float'],
#  ['eat', 'throw', 'grow'],
#  ['have', 'hooks', 'help'],
#  ['have'],
#  ['stick', 'are', 'carried'],
#  ['eat', 'pass', 'are', 'dispersed'],
#  ['eating'],
#  ['had'],
#  ['are', 'spongy', 'have', 'covering', 'help', 'float'],
#  ['transports'],
#  ['travel'],
#  ['grew', 'carried'],
#  ['burst', 'are', 'scattering'],
#  ['is', 'called'],
#  ['is', 'ground', 'are'],
#  ['is', 'sifted', 'find', 'left'],
#  ['are'],
#  ['is'],
#  ['has'],
#  ['help', 'move'],
#  ['is'],
#  ['helps', 'form'],
#  ['is', 'called'],
#  ['are'],
#  ['does', 'contain', 'lead'],
#  ['have', 'learnt'],
#  ['are', 'called'],
#  ['is', 'provide'],
#  ['are', 'needed', 'are'],
#  [],
#  ['gets', 'injured'],
#  ['goes', 'being'],
#  ['are'],
#  ['are', 'required', 'growing'],
#  ['are'],
#  ['get', 'include'],
#  ['are', 'are'],
#  ['are', 'needed', 'have', 'play'],
#  ['is', 'carrying'],
#  ['is', 'does', 'get'],
#  ['is', 'called'],
#  ['germinate', 'grow'],
#  ['makes'],
#  ['sprouted', 'are'],
#  ['is', 'eat', 'sift', 'throw'],
#  ['Hold', 'keep'],
#  ['do', 'feel'],
#  ['observe', 'do', 'see'],
#  ['Living', 'need', 'live'],
#  ['Inhaling', 'exhaling', 'formed', 'is', 'called'],
#  ['snake', 'have'],
#  ['respire'],
#  ['grow'],
#  ['is'],
#  ['have'],
#  ['bear'],
#  ['are', 'called'],
#  ['are', 'live'],
#  ['flows'],
#  ['are'],
#  ['is', 'called'],
#  ['is', 'heated', 'becomes'],
#  ['shows', 'allow', 'flow'],
#  ['is', 'called'],
#  ['have'],
#  ['has', 'be', 'identified'],
#  ['look', 'see', 'is', 'said', 'be'],
#  ['name', 'is', 'grown'],
#  ['are'],
#  ['maturing', 'covered', 'be', 'seen'],
#  ['Have', 'seen', 'is', 'picking'],
#  ['looks', 'covered', 'is', 'picked'],
#  ['are', 'separated', 'combing'],
#  ['is', 'called'],
#  ['Ginning', 'was', 'done'],
#  ['are', 'used', 'ginning']]

# %%
data = {'sentence':df1['sentence'],'n_list':listofnouns,'v_list':listofverbs}

# %%
new_df = pd.DataFrame(data)

# %%
new_df
# Out:
#                                               sentence  \
# 0    There are six main nutrients in our food : Car...
# 1    These nutrients are present in the different f...
# 2                          Our main need is of energy.
# 3                 Let us learn more about some of them
# 4                     It is fulfilled by carbohydrates
# ..                                                 ...
# 230  It looks like a field covered with snow.na Fro...
# 231  Fibres are then separated from the seeds by co...
# 232          This process is called ginning of cotton.
# 233   Ginning was traditionally done by hand (Fig.3.7)
# 234    These days, machines are also used for ginning.
#
#                                                 n_list  \
# 0    [six main nutrients, our food, Carbohydrates, ...
# 1    [These nutrients, the different food items, we...
# 2                              [Our main need, energy]
# 3                                     [us, some, them]
# 4                                  [It, carbohydrates]
# ..                                                 ...
# 230  [It, a field, snow.na, these bolls, cotton, hand]
# 231                                [Fibres, the seeds]
# 232                    [This process, ginning, cotton]
# 233                          [Ginning, hand, (Fig.3.7]
# 234                                [machines, ginning]
#
#                            v_list
# 0                           [are]
# 1           [are, eat, differing]
# 2                            [is]
# 3                    [Let, learn]
# 4                 [is, fulfilled]
# ..                            ...
# 230  [looks, covered, is, picked]
# 231     [are, separated, combing]
# 232                  [is, called]
# 233          [Ginning, was, done]
# 234          [are, used, ginning]
#
# [235 rows x 3 columns]

# %% [markdown]
# ## getting Count of noun chunks and verbs .

# %%
noofnouns = []
noofverbs = []
for i in listofnouns:
  noofnouns.append(len(i))
for i in listofverbs:
  noofverbs.append(len(i))

# %%
month = df1['n(list)'].tolist()

# %%
listof = []
for i in month:
  listof.append(i)

# %%
noofnouns_insheet = []
noofverbs_insheet = []
for i in df1['n(list)'].tolist():
  noofnouns_insheet.append(len(i.split(',')))
for i in df1['v(list)'].tolist():
   noofverbs_insheet.append(len(i.split(',')))

# %%
noun_nomatch = []
verb_nomatch = []
for i in range(len(noofnouns)):
  noun_nomatch.append(noofnouns_insheet[i]-noofnouns[i])
for i in range(len(noofverbs)):
  verb_nomatch.append(noofverbs_insheet[i]-noofverbs[i])

# %%
len(df1['n(list)'])
# Out:
# 235

# %%
exact_mat_noun = []
exact_mat_verb = []
for i in range(len(df1['n(list)'])):
  exact_mat_noun.append(min(noofnouns[i],noofnouns_insheet[i]))
  exact_mat_verb.append(min(noofverbs[i],noofverbs_insheet[i]))

# %%
datacount = {'N(excel)':noofnouns_insheet,'N(text file)':noofnouns,'N(Exact_match)':exact_mat_noun,'N(no match)':noun_nomatch,'V(excel)':noofverbs_insheet,'V(text file)':noofverbs,'V(no match)':verb_nomatch,'V(Exact_match)':exact_mat_verb}

# %%
datacount_df = pd.DataFrame(datacount)

# %%
datacount_df
# Out:
#      N(excel)  N(text file)  N(Exact_match)  N(no match)  V(excel)  \
# 0           9             8               8            1         1
# 1           4             4               4            0         2
# 2           2             2               2            0         1
# 3           3             3               3            0         2
# 4           2             2               2            0         1
# ..        ...           ...             ...          ...       ...
# 230         6             6               6            0         3
# 231         2             2               2            0         2
# 232         3             3               3            0         1
# 233         2             3               2           -1         1
# 234         2             2               2            0         2
#
#      V(text file)  V(no match)  V(Exact_match)
# 0               1            0               1
# 1               3           -1               2
# 2               1            0               1
# 3               2            0               2
# 4               2           -1               1
# ..            ...          ...             ...
# 230             4           -1               3
# 231             3           -1               2
# 232             2           -1               1
# 233             3           -2               1
# 234             3           -1               2
#
# [235 rows x 8 columns]

# %%
total_N_excel = datacount_df['N(excel)'].sum()
total_text_file = datacount_df['N(text file)'].sum()
total_nomatch = datacount_df['N(no match)'].sum()
total_exa = datacount_df['N(Exact_match)'].sum()
total_V_excel = datacount_df['V(excel)'].sum()
total_V_text = datacount_df['V(text file)'].sum()
total_V_nomatch = datacount_df['V(no match)'].sum()
total_V_exa = datacount_df['V(Exact_match)'].sum()

# %%
per_noun = (total_exa)/total_N_excel

# %%
total_N_excel
# Out:
# 1037

# %%
total_exa
# Out:
# 1012

# %%
per_noun*100   # 97.03947368421053 for science-dataset2 # 97.58 for science Dataset1 # 93.6 for Dataset3
# Out:
# 97.58919961427193

# %%
per_verb = (total_V_exa)/total_V_excel

# %%
per_verb*100 # 91.71597633136095  for science-dataset2 # 96.00 for science Dataset1 # 92.93 for Dataset3
# Out:
# 96.0
